# %% [markdown]
# # Descriptor Prototyping
#
# Scratchpad for RDKit-based descriptor calculations used in the Early Drug Discovery Screening Dashboard (EDDSD).
#
# - Mirrors PRD sections 4.4 and 4.5
# - Goal: document exactly which RDKit descriptors are used and how
# - Output: code and comments that can be migrated into `backend/app/chemistry.py`

# %%
from rdkit import Chem
from rdkit.Chem import Crippen, Descriptors, Lipinski, rdMolDescriptors

smiles = "CCOc1ccccc1O"  # example scaffold
mol = Chem.MolFromSmiles(smiles)

Descriptors.MolWt(mol), Crippen.MolLogP(mol), rdMolDescriptors.CalcTPSA(mol)
