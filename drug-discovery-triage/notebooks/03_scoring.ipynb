# %% [markdown]
# # Fail-Fast Drug-Likeness Scoring
#
# Notebook documenting the heuristic scoring scheme from the PRD:
#
# - 35% Lipinski compliance
# - 25% medicinal chemistry alerts
# - 20% synthetic accessibility
# - 10% flexibility
# - 10% complexity
#
# This should mirror and justify the implementation in `backend/app/chemistry.py` (`_fail_fast_score`).

# %%
def fail_fast_score_demo(lipinski_summary: str, n_alerts: int, sas_score: float,
                         n_flex_warnings: int, n_comp_warnings: int) -> float:
    # Placeholder to prototype scoring tweaks before migrating into the backend.
    return 0.0

fail_fast_score_demo("Pass", 0, 3.0, 0, 0)
